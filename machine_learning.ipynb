# %% [markdown]
# <a href="https://colab.research.google.com/github/MwikaliDev/DataScience_project/blob/main/machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def volume(L,W,H):
  return L*W*H
# Calling the function with the given arguments
vol1 = volume(25, 5, 6)
vol2 = volume(63, 9, 4)
vol3 = volume(70, 16, 5)

print(f"Volume of tank 1: {vol1}")
print(f"Volume of tank 2: {vol2}")
print(f"Volume of tank 3: {vol3}")
# Out:
# Volume of tank 1: 750
# Volume of tank 2: 2268
# Volume of tank 3: 5600

# %%
x=6,7,8
if x[0] > 0:
  print("x is positive")
elif x[0] < 0:
  print("x is negative")
else:
  print("x is zero")
# Out:
# x is positive

# %%
def HelloWorld():
  print("Hello World!")
HelloWorld()
#call it HelloWorld()
# Out:
# Hello World!

# %%
def my_function (fname):
  print(fname)
my_function("winfred")
my_function("mwikali")
my_function("maluki")
# Out:
# winfred
# mwikali
# maluki

# %%
def no_of_trays (eggs):
  trays=eggs//30
  bal=eggs %30
  total=trays+bal/30
  return total
  x=no_of_trays(90)
  print("no of trays:"+x)

print(no_of_trays(90))
# Out:
# 3.0

# %% [markdown]
# calculating the volume

# %%
def volume(L,W,H):
  return L*W*H
# Calling the function with the given arguments
vol1 = volume(2, 5, 5)
vol2 = volume(6, 9, 4)
vol3 = volume(10, 12, 5)

print(f"Volume of tank 1: {vol1}")
print(f"Volume of tank 2: {vol2}")
print(f"Volume of tank 3: {vol3}")
# Out:
# Volume of tank 1: 50
# Volume of tank 2: 216
# Volume of tank 3: 600

# %%
import pandas as pd
from google.colab import files
uploaded=files.upload()
df=pd.read_csv("childhealthdata.csv")
#df.head()
#print(df.describe())
#print(df['education'].unique())
#print(df["education"].value_counts())
#df['age_in_days'] = df['age'] * 365
#df.tail()
#df.isna().sum()
#duplicated_rows=df[df.duplicated()]
#print(duplicated_rows)
#df['education']=df['education'].str.upper()
#df.head()
#df_above_30=df[df['age']>=30]
#df_above_30.head()
df_18=df[(df['age']==18) & (df['education']=='Female')]
df_18.head()
# Out:
#      <input type="file" id="files-0d110a51-6580-4cd7-9e65-d920a3934130" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d110a51-6580-4cd7-9e65-d920a3934130">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Working with matplotlib

import matplotlib.pyplot as plt
import pandas as pd
from google.colab import files
uploaded=files.upload()
data=pd.read_csv('childhealthdata.csv')
#print(data.shape)
data.head()
#data.columns
#data.dtypes
# Out:
#      <input type="file" id="files-1aa67a20-9957-4794-9c86-6fe89dcbd639" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1aa67a20-9957-4794-9c86-6fe89dcbd639">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Plotting the pie chart code
import matplotlib.pyplot as plt

gender_counts = df['Sex'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution by gender')
plt.axis('equal')
plt.show()

# %%
#Plotting the bar chart

education_counts = df['education'].value_counts()
plt.figure(figsize=(10, 6))
plt.bar(education_counts.index, education_counts.values, color='skyblue')
plt.xlabel('education')
plt.ylabel('Count')
plt.title('Distribution by education')
plt.xticks(rotation=45)  # Rotate labels if needed for better readability
plt.show()

# %%
# Create the histogram
plt.figure(figsize=(8, 6))
plt.hist(df['age'], bins=10, color='skyblue', edgecolor='black')
plt.title('Distribution of age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#Plotting a line chart

data = {
    'month': ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'],
    'reported_cases': [90, 80, 70, 75, 90, 85, 80, 100,90, 85, 100, 140]
}

# %%
df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))
plt.plot(df['month'], df['reported_cases'], marker='o')
plt.xlabel('Month')
plt.ylabel('Reported Cases')
plt.title('Reported Cases Over Time')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()
